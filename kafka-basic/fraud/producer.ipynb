# %%
from kafka import KafkaProducer
import json
import time
import random

producer = KafkaProducer(
    bootstrap_servers=['kafka:9092'],
    value_serializer=lambda v: json.dumps(v).encode('utf-8')
)

user_ids = [101, 102, 103, 104, 105]

print("Starting Transaction Producer...")

for i in range(100):
    tx_data = {
        "tx_id": i,
        "userId": random.choice(user_ids),
        "amount": round(random.uniform(10.0, 15000.0), 2),  # >10000 triggers fraud
        "timestamp": time.time()
    }
    producer.send('fraud-detection', value=tx_data)
    print(f"Sent: {tx_data}")
    time.sleep(2)

producer.flush()
# Out:
# Starting Transaction Producer...
# Sent: {'tx_id': 0, 'userId': 104, 'amount': 106.67, 'timestamp': 1781858698.6064742}
# Sent: {'tx_id': 1, 'userId': 101, 'amount': 10808.11, 'timestamp': 1781858700.705421}
# Sent: {'tx_id': 2, 'userId': 104, 'amount': 5178.55, 'timestamp': 1781858702.7060466}
# Sent: {'tx_id': 3, 'userId': 101, 'amount': 8731.33, 'timestamp': 1781858704.7066765}
# Sent: {'tx_id': 4, 'userId': 105, 'amount': 9536.51, 'timestamp': 1781858706.707726}
# Sent: {'tx_id': 5, 'userId': 103, 'amount': 12425.13, 'timestamp': 1781858708.7090394}
# Sent: {'tx_id': 6, 'userId': 101, 'amount': 1904.51, 'timestamp': 1781858710.7101753}
# Sent: {'tx_id': 7, 'userId': 104, 'amount': 2181.15, 'timestamp': 1781858712.710814}
# Sent: {'tx_id': 8, 'userId': 101, 'amount': 3489.81, 'timestamp': 1781858714.7114563}
# Sent: {'tx_id': 9, 'userId': 104, 'amount': 13385.38, 'timestamp': 1781858716.712116}
# Sent: {'tx_id': 10, 'userId': 103, 'amount': 10547.32, 'timestamp': 1781858718.713583}
# Sent: {'tx_id': 11, 'userId': 101, 'amount': 8316.57, 'timestamp': 1781858720.7153902}
# Sent: {'tx_id': 12, 'userId': 102, 'amount': 6623.68, 'timestamp': 1781858722.7158027}
# Sent: {'tx_id': 13, 'userId': 103, 'amount': 12916.65, 'timestamp': 1781858724.7170527}
# Sent: {'tx_id': 14, 'userId': 103, 'amount': 14337.33, 'timestamp': 1781858726.7175376}
# Sent: {'tx_id': 15, 'userId': 105, 'amount': 2570.3, 'timestamp': 1781858728.7181528}
# Sent: {'tx_id': 16, 'userId': 103, 'amount': 12900.71, 'timestamp': 1781858730.719377}
# Sent: {'tx_id': 17, 'userId': 101, 'amount': 12049.64, 'timestamp': 1781858732.7200444}
# Sent: {'tx_id': 18, 'userId': 101, 'amount': 14090.45, 'timestamp': 1781858734.7205114}
# Sent: {'tx_id': 19, 'userId': 105, 'amount': 13919.3, 'timestamp': 1781858736.7220354}
# Sent: {'tx_id': 20, 'userId': 101, 'amount': 10885.56, 'timestamp': 1781858738.7228496}
# Sent: {'tx_id': 21, 'userId': 103, 'amount': 10354.16, 'timestamp': 1781858740.7242284}
# Sent: {'tx_id': 22, 'userId': 102, 'amount': 4789.08, 'timestamp': 1781858742.7254}
# Sent: {'tx_id': 23, 'userId': 103, 'amount': 4271.7, 'timestamp': 1781858744.7264252}
# Sent: {'tx_id': 24, 'userId': 104, 'amount': 2758.08, 'timestamp': 1781858746.7269213}
# Sent: {'tx_id': 25, 'userId': 104, 'amount': 14620.58, 'timestamp': 1781858748.7273786}
# Sent: {'tx_id': 26, 'userId': 102, 'amount': 6253.45, 'timestamp': 1781858750.728725}
# Sent: {'tx_id': 27, 'userId': 103, 'amount': 12108.43, 'timestamp': 1781858752.729736}
# Sent: {'tx_id': 28, 'userId': 101, 'amount': 6271.03, 'timestamp': 1781858754.7304513}
# Sent: {'tx_id': 29, 'userId': 103, 'amount': 2215.14, 'timestamp': 1781858756.7314835}
# Sent: {'tx_id': 30, 'userId': 105, 'amount': 13282.76, 'timestamp': 1781858758.7318869}
# Sent: {'tx_id': 31, 'userId': 105, 'amount': 7656.05, 'timestamp': 1781858760.7330909}
# Sent: {'tx_id': 32, 'userId': 105, 'amount': 4473.32, 'timestamp': 1781858762.7353494}
# Sent: {'tx_id': 33, 'userId': 101, 'amount': 7833.06, 'timestamp': 1781858764.7365484}
# Sent: {'tx_id': 34, 'userId': 104, 'amount': 507.25, 'timestamp': 1781858766.737884}
# Sent: {'tx_id': 35, 'userId': 101, 'amount': 13366.0, 'timestamp': 1781858768.7392073}
# Sent: {'tx_id': 36, 'userId': 102, 'amount': 12841.19, 'timestamp': 1781858770.7403986}
# Sent: {'tx_id': 37, 'userId': 104, 'amount': 14345.5, 'timestamp': 1781858772.7414906}
# Sent: {'tx_id': 38, 'userId': 101, 'amount': 7075.13, 'timestamp': 1781858774.7427692}
# Sent: {'tx_id': 39, 'userId': 101, 'amount': 1614.45, 'timestamp': 1781858776.7469714}
# Sent: {'tx_id': 40, 'userId': 101, 'amount': 7119.37, 'timestamp': 1781858778.7474434}
# Sent: {'tx_id': 41, 'userId': 105, 'amount': 11303.99, 'timestamp': 1781858780.748437}
# Sent: {'tx_id': 42, 'userId': 104, 'amount': 12212.65, 'timestamp': 1781858782.7488875}
# Sent: {'tx_id': 43, 'userId': 101, 'amount': 14487.18, 'timestamp': 1781858784.75028}
# Sent: {'tx_id': 44, 'userId': 101, 'amount': 1425.11, 'timestamp': 1781858786.7513578}
# Sent: {'tx_id': 45, 'userId': 103, 'amount': 8668.34, 'timestamp': 1781858788.752714}
# Sent: {'tx_id': 46, 'userId': 103, 'amount': 9509.73, 'timestamp': 1781858790.7539208}
# Sent: {'tx_id': 47, 'userId': 101, 'amount': 12096.68, 'timestamp': 1781858792.7551997}
# Sent: {'tx_id': 48, 'userId': 102, 'amount': 14680.89, 'timestamp': 1781858794.755787}
# Sent: {'tx_id': 49, 'userId': 105, 'amount': 10136.47, 'timestamp': 1781858796.7570198}
# Sent: {'tx_id': 50, 'userId': 104, 'amount': 1307.66, 'timestamp': 1781858798.7574472}
# Sent: {'tx_id': 51, 'userId': 102, 'amount': 4399.18, 'timestamp': 1781858800.757868}
# Sent: {'tx_id': 52, 'userId': 101, 'amount': 11804.0, 'timestamp': 1781858802.759205}
# Sent: {'tx_id': 53, 'userId': 103, 'amount': 2294.72, 'timestamp': 1781858804.7602477}
# Sent: {'tx_id': 54, 'userId': 102, 'amount': 8414.27, 'timestamp': 1781858806.7633116}
# Sent: {'tx_id': 55, 'userId': 105, 'amount': 2802.73, 'timestamp': 1781858808.7637665}
# Sent: {'tx_id': 56, 'userId': 105, 'amount': 5223.99, 'timestamp': 1781858810.7642338}
# Sent: {'tx_id': 57, 'userId': 103, 'amount': 2762.1, 'timestamp': 1781858812.7652273}
# Sent: {'tx_id': 58, 'userId': 101, 'amount': 6452.93, 'timestamp': 1781858814.7664387}
# Sent: {'tx_id': 59, 'userId': 105, 'amount': 12437.37, 'timestamp': 1781858816.7669878}
# Sent: {'tx_id': 60, 'userId': 103, 'amount': 12429.77, 'timestamp': 1781858818.7679899}
# Sent: {'tx_id': 61, 'userId': 104, 'amount': 2472.57, 'timestamp': 1781858820.7711058}
# Sent: {'tx_id': 62, 'userId': 101, 'amount': 444.68, 'timestamp': 1781858822.7720664}
# Sent: {'tx_id': 63, 'userId': 104, 'amount': 9005.9, 'timestamp': 1781858824.772532}
# Sent: {'tx_id': 64, 'userId': 105, 'amount': 12619.13, 'timestamp': 1781858826.7738445}
# Sent: {'tx_id': 65, 'userId': 104, 'amount': 5463.74, 'timestamp': 1781858828.7748654}
# Sent: {'tx_id': 66, 'userId': 105, 'amount': 286.7, 'timestamp': 1781858830.7767708}
# Sent: {'tx_id': 67, 'userId': 101, 'amount': 4292.78, 'timestamp': 1781858832.7772803}
# Sent: {'tx_id': 68, 'userId': 101, 'amount': 4634.8, 'timestamp': 1781858834.7785356}
# Sent: {'tx_id': 69, 'userId': 104, 'amount': 13226.02, 'timestamp': 1781858836.7800212}
# Sent: {'tx_id': 70, 'userId': 103, 'amount': 11646.32, 'timestamp': 1781858838.7804935}
# Sent: {'tx_id': 71, 'userId': 102, 'amount': 14263.94, 'timestamp': 1781858840.7815106}
# Sent: {'tx_id': 72, 'userId': 103, 'amount': 14027.14, 'timestamp': 1781858842.7820015}
# Sent: {'tx_id': 73, 'userId': 105, 'amount': 707.54, 'timestamp': 1781858844.782594}
# Sent: {'tx_id': 74, 'userId': 101, 'amount': 9730.82, 'timestamp': 1781858846.7837641}
# Sent: {'tx_id': 75, 'userId': 104, 'amount': 12102.01, 'timestamp': 1781858848.7848792}
# Sent: {'tx_id': 76, 'userId': 102, 'amount': 2626.22, 'timestamp': 1781858850.78546}
# Sent: {'tx_id': 77, 'userId': 104, 'amount': 5590.61, 'timestamp': 1781858852.7864904}
# Sent: {'tx_id': 78, 'userId': 104, 'amount': 11096.9, 'timestamp': 1781858854.7868836}
# Sent: {'tx_id': 79, 'userId': 103, 'amount': 10223.39, 'timestamp': 1781858856.7880638}
# Sent: {'tx_id': 80, 'userId': 102, 'amount': 1259.49, 'timestamp': 1781858858.7886257}
# Sent: {'tx_id': 81, 'userId': 105, 'amount': 5862.85, 'timestamp': 1781858860.789939}
# Sent: {'tx_id': 82, 'userId': 104, 'amount': 12651.99, 'timestamp': 1781858862.7918875}
# Sent: {'tx_id': 83, 'userId': 101, 'amount': 14135.58, 'timestamp': 1781858864.7929423}
# Sent: {'tx_id': 84, 'userId': 101, 'amount': 8841.89, 'timestamp': 1781858866.7933836}
# Sent: {'tx_id': 85, 'userId': 104, 'amount': 5427.04, 'timestamp': 1781858868.7946272}
# Sent: {'tx_id': 86, 'userId': 104, 'amount': 10300.76, 'timestamp': 1781858870.7952447}
# Sent: {'tx_id': 87, 'userId': 103, 'amount': 6782.26, 'timestamp': 1781858872.7958834}
# Sent: {'tx_id': 88, 'userId': 102, 'amount': 11272.14, 'timestamp': 1781858874.7976637}
# Sent: {'tx_id': 89, 'userId': 101, 'amount': 11563.53, 'timestamp': 1781858876.798155}
# Sent: {'tx_id': 90, 'userId': 102, 'amount': 5687.82, 'timestamp': 1781858878.7987707}
# Sent: {'tx_id': 91, 'userId': 103, 'amount': 14719.3, 'timestamp': 1781858880.7999911}
# Sent: {'tx_id': 92, 'userId': 101, 'amount': 9543.18, 'timestamp': 1781858882.8005757}
# Sent: {'tx_id': 93, 'userId': 101, 'amount': 7527.74, 'timestamp': 1781858884.8010254}
# Sent: {'tx_id': 94, 'userId': 105, 'amount': 14005.06, 'timestamp': 1781858886.802283}
# Sent: {'tx_id': 95, 'userId': 101, 'amount': 3758.09, 'timestamp': 1781858888.8029861}
# Sent: {'tx_id': 96, 'userId': 101, 'amount': 8800.59, 'timestamp': 1781858890.8036199}
# Sent: {'tx_id': 97, 'userId': 102, 'amount': 915.26, 'timestamp': 1781858892.8042192}
# Sent: {'tx_id': 98, 'userId': 105, 'amount': 8959.58, 'timestamp': 1781858894.8055713}
# Sent: {'tx_id': 99, 'userId': 105, 'amount': 2820.61, 'timestamp': 1781858896.8060057}
